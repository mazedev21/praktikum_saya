# %% [markdown]
# <a href="https://colab.research.google.com/github/mazedev21/praktikum_saya/blob/main/struktur_data/Pertemuan6_sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bubble sort

def bubble_sort(arr):
  n = len(arr)
  for i in range(n-1):
    for j in range(n - i - 1):
      if arr[j] > arr[j + 1]:
        arr[j], arr[j + 1] = arr[j + 1], arr[j]
  return arr

#Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy()) #mengggunakan copy agar data asli tidak berubah
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
#Selection sort

def selection_sort(arr):
  n = len(arr)
  for i in range(n-1):
    min_index = i
    for j in range(i + 1, n):
      if arr[j] < arr[min_index]:
        min_index = j
    arr[i], arr[min_index], = arr[min_index], arr[i]
  return arr

#Contoh penggunan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %%
#Insertion Sort

def insertion_sort(arr):
  n = len(arr)
  for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key
  return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
#Merge Sort

def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0

    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
        k += 1

    while i < len(left_half):
      arr[k] = left_half[i]
      i += 1
      k += 1

    while j < len(right_half):
      arr[k] = right_half[j]
      j += 1
      k += 1

  return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 22, 11, 25, 64]

# %%
#Quick Sort
def quick_sort(arr):
  if len(arr) <= 1:
    return arr
  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]

  return quick_sort(left) + middle + quick_sort(right)

#Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %%
class Konsumen:
  def __init__(self, nama, usia, total_belanja):
    self.nama = nama
    self.usia = usia
    self.total_belanja = total_belanja

def quick_sort(data):
  if len(data) <= 1:
    return data
  pivot = data[len(data) // 2]

  def key(x):
    return (x.nama, x.usia, x.total_belanja)

  left = [x for x in data if key(x) < key(pivot)]
  middle = [x for x in data if key(x) == key(pivot)]
  right = [x for x in data if key(x) > key(pivot)]

  return quick_sort(left) + middle + quick_sort(right)

#Penggunaan
data = [
    Konsumen("Henji", 19, 50),
    Konsumen("Agung", 30, 20),
    Konsumen("Agus", 20, 22)
]
sorted_data = quick_sort(data.copy())

print("Data sebelum sort:")
for i in data:
  print(i.nama, i.usia, i.total_belanja)
print("\nData setelah Quick Sort:")
for j in sorted_data:
  print(j.nama, j.usia, j.total_belanja)
# Out:
# Data sebelum sort:
# Henji 19 50
# Agung 30 20
# Agus 20 22
#
# Data setelah Quick Sort:
# Agung 30 20
# Agus 20 22
# Henji 19 50
